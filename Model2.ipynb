# %% [markdown]
# <h1><center>TCEasy: Trichloroethylene Bioremiediaton</center></h1>
#
# <h2></h2>
#
#
# <sup>[1](#myfootnote1)</sup>
#
#
#
# <a name="Tellurium">1</a>: <a href="http://tellurium.analogmachine.org/">Tellurium</a>

# %%
import numpy as np
import tellurium as te
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
model = te.loada('''
    compartment C100;
    C1 = 1;
    species TCE, Epoxide, Dichloroactate, LossOfOneCL, Glyoxylate, Output;

    TCE = 1.0;
    Epoxide = 0;
    Dichloroactate = 0;
    LossOfOneCL = 0;
    Glyoxylate = 0;
    Output = 0;
    
    TCE in C1; Epoxide in C1; Dichloroactate in C1; LossOfOneCL in C1; Glyoxylate in C1; Output in C1;
    
    J1: TCE -> Epoxide; k2*TCE*PopulationVariable1; 
    J2: Epoxide -> Dichloroactate; k3*Epoxide/4;
    J3: Dichloroactate -> LossOfOneCL; k4*Dichloroactate*PopulationVariable2;
    J4: LossOfOneCL -> Glyoxylate; PopulationVariable3*k4*LossOfOneCL;
    J5: Glyoxylate -> Output; k5*Glyoxylate*PopulationVariable3*k1

    k1 = .00045;
    k2 = .4;
    k3 = .49;
    k4 = 500;
    k5 = 500;
    
    PopulationVariable1=50;
    PopulationVariable2=50;
    PopulationVariable3=50;

''')

# %%
model.integrator.setValue('maximum_num_steps', 2000000)
model.reset()

# %%
def Population1(x):
    model.reset()
    model.PopulationVariable1 = x
    model.simulate(0, 45, 1000)
    z = model.plot()
    model.show(z)
    
def Population2(x):
    model.reset()
    model.PopulationVariable2 = x
    model.simulate(0, 45, 1000)
    z = model.plot()
    model.show(z)

def Population3(x):
    model.reset()
    model.PopulationVariable3 = x
    model.simulate(0, 45, 1000)
    z = model.plot()
    model.show(z)

def CompartmentSize(x):
    model.reset()
    model.C1 = x
    model.simulate(0, 45, 1000)
    z = model.plot()
    model.show(z)
    

interact(CompartmentSize, x=(1,100))
interact(Population1, x=(0, 100));
interact(Population2, x=(0, 100));
interact(Population3, x=(0, 100));
# Out:
# <div id="20cfe7b6-6549-4c09-ae18-58722e07a976" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("20cfe7b6-6549-4c09-ae18-58722e07a976", [{"type": "scatter", "x": [0.0, 0.04504504504504504, 0.09009009009009009, 0.13513513513513514, 0.18018018018018017, 0.2252252252252252, 0.2702702702702703, 0.3153153153153153, 0.36036036036036034, 0.4054054054054054, 0.4504504504504504, 0.4954954954954955, 0.5405405405405406, 0.5855855855855856, 0.6306306306306306, 0.6756756756756757, 0.7207207207207207, 0.7657657657657657, 0.8108108108108107, 0.8558558558558558, 0.9009009009009008, 0.9459459459459459, 0.990990990990991, 1.036036036036036, 1.0810810810810811, 1.1261261261261262, 1.1711711711711712, 1.2162162162162162, 1.2612612612612613, 1.3063063063063063, 1.3513513513513513, 1.3963963963963963, 1.4414414414414414, 
# ...

# %%
model.reset()
result = model.gillespie (0, 45, 1000, ['time', 'TCE', 'Epoxide', 'Dichloroactate', 'LossOfOneCL', 'Glyoxylate', 'Output' ])
model.plot(result)
# Out:
# <div id="81c26a59-3eaf-4e9a-975d-3371121308fd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("81c26a59-3eaf-4e9a-975d-3371121308fd", [{"type": "scatter", "x": [0.0, 0.04504504504504504, 0.09009009009009009, 0.13513513513513514, 0.18018018018018017, 0.2252252252252252, 0.2702702702702703, 0.3153153153153153, 0.36036036036036034, 0.4054054054054054, 0.4504504504504504, 0.4954954954954955, 0.5405405405405406, 0.5855855855855856, 0.6306306306306306, 0.6756756756756757, 0.7207207207207207, 0.7657657657657657, 0.8108108108108107, 0.8558558558558558, 0.9009009009009008, 0.9459459459459459, 0.990990990990991, 1.036036036036036, 1.0810810810810811, 1.1261261261261262, 1.1711711711711712, 1.2162162162162162, 1.2612612612612613, 1.3063063063063063, 1.3513513513513513, 1.3963963963963963, 1.4414414414414414, 
# ...

# %%
model.draw(width=300)
model.conservedMoietyAnalysis = True
model.plot(result);
